# %%
from sklearn.datasets import make_classification
import numpy as np
X,y = make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)

# %%
def step(x):
    return 1 if x >= 0 else 0

# %%
def Perceptron(X, y):
    X = np.insert(X, 0, 1, axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.1

    for i in range(10000):
        j = np.random.randint(0, 100)
        y_hat = step(np.dot(X[j], weights))
        weights = weights + lr * (y[j] - y_hat) * X[j]
    return weights[0], weights[1:]

# %%
# Train
intercept_, coeff_ = Perceptron(X, y)
print(intercept_, coeff_)
# Out:
# 1.0 [1.41378589 0.11163936]

# %%
m = -(coeff_[0] / coeff_[1])
b = -(intercept_ / coeff_[1])

# %%
x_input = np.linspace(-3, 3, 100)
y_line = m * x_input + b  # renamed to avoid overwriting labels

# %%
plt.figure(figsize=(10, 6))
plt.plot(x_input, y_line, color='red', linewidth=3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=100)
plt.ylim(-3, 2)
plt.show()
